# %%
import openpyxl
import os
import sys

# %%
os.chdir('C:\Syntax')

wb = openpyxl.load_workbook('groceries_updated.xlsx')

# %%
type(wb)#
# Out:
# openpyxl.workbook.workbook.Workbook

# %%
wb.get_sheet_names()
# Out:
# <ipython-input-10-3dbf5bc11a2f>:1: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   wb.get_sheet_names()
# ['Sheet1']

# %%
sheet = wb.get_sheet_by_name('Sheet1')
# Out:
# <ipython-input-12-0ba8255b6bc7>:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   sheet = wb.get_sheet_by_name('Sheet1')

# %%
type(sheet)
# Out:
# openpyxl.worksheet.worksheet.Worksheet

# %%
sheet['A1']
# Out:
# <Cell 'Sheet1'.A1>

# %%
c = sheet['A1'] 
print ('Value:' + (c.value))
# Out:
# Value:id

# %%
SRow = str(c.row) 
SC = str(c.column) 
SCoord = c.coordinate

# %%
print (SRow,SC,SCoord)
# Out:
# 1 1 A1

# %%
testcellval = sheet.cell(row=1,column=2).value

# %%
print(testcellval)
# Out:
# item1

# %%
dataarray = []

# %%
dataarray.append('val1')

# %%
print(dataarray)
# Out:
# ['val1']

# %%
dataarray.pop(0)
# Out:
# 'val1'

# %%
print(dataarray)
# Out:
# []

# %%
c2 = sheet['E2'] 
print ('Value:' + (c2.value))
# Out:
# Value:ready soups

# %%
SRow2 = str(c2.row) 
SC2 = str(c2.column) 
SCoord2 = c2.coordinate
print (SRow2,SC2,SCoord2)
# Out:
# 2 5 E2

# %%
testcellval2 = sheet.cell(row=2,column=5).value 
print(testcellval2)
# Out:
# ready soups

# %%
sheet = wb['Sheet1']

# %%
for row in sheet.rows:
    print(row[1].value)
# Out:
# item1
# citrus fruit
# tropical fruit
# whole milk
# pip fruit
# other vegetables
# whole milk
# rolls/buns
# other vegetables
# potted plants
# whole milk
# tropical fruit
# citrus fruit
# beef
# frankfurter
# chicken
# butter
# fruit/vegetable juice
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
resultFile = open('groceries_alina','w')

# %%
resultFile.write('selected rows ='+ str(dataarray))
# Out:
# 17
